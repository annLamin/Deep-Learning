# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS= 3
EPOCHS = 10

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "PlantVillage",
    shuffle=True,
    image_size= (IMAGE_SIZE,IMAGE_SIZE),
    batch_size= BATCH_SIZE
)
# Out:
# Found 16011 files belonging to 10 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Tomato_Bacterial_spot',
#  'Tomato_Early_blight',
#  'Tomato_Late_blight',
#  'Tomato_Leaf_Mold',
#  'Tomato_Septoria_leaf_spot',
#  'Tomato_Spider_mites_Two_spotted_spider_mite',
#  'Tomato__Target_Spot',
#  'Tomato__Tomato_YellowLeaf__Curl_Virus',
#  'Tomato__Tomato_mosaic_virus',
#  'Tomato_healthy']

# %%
len(dataset)
# Out:
# 501

# %%
for image_batch, label_batch in dataset.take(1):
    plt.imshow(image_batch[0].numpy().astype("uint8"))
    plt.axis("off")
    # print(image_batch[0].shape)

# %%
plt.figure(figsize=(10,10))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
# 80% ==> training
# 20% ==> 10% validation, 10% test

# %%
train_size = 0.8
len(dataset)*train_size
# Out:
# 400.8

# %%
train_ds = dataset.take(400)
len(train_ds)
# Out:
# 400

# %%
test_ds = dataset.skip(400)
len(test_ds)
# Out:
# 101

# %%
val_size = 0.1
len(dataset)*val_size
# Out:
# 50.1

# %%
val_ds = test_ds.skip(50)
len(val_ds)
# Out:
# 51

# %%
def get_dataset_partitioning_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
        ds_size = len(ds)
        if shuffle:
            df = ds.shuffle(shuffle_size, seed=12)
        train_size = int(train_split * ds_size)
        val_size = int(val_split * ds_size)
        train_ds = ds.take(train_size)
        val_ds = ds.skip(train_size).take(val_size)
        test_ds = ds.skip(train_size).take(val_size)
        return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds= get_dataset_partitioning_tf(dataset)

# %%
len(train_ds)
# Out:
# 400

# %%
len(val_ds)
# Out:
# 50

# %%
len(test_ds)
# Out:
# 50

# %%
train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# ##### Resizing the images, even thought they are 256 but the layers will go to the ult model and if there are images that are not 256 it will take care of resizing it.

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE,IMAGE_SIZE),
    layers.Rescaling(1.0/255)
    
])

# %% [markdown]
# ###### Data Ugmentation: for the robustness of the model. This help to rotate the images and also add more images for the robustness of the model.

# %%
data_ugmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2)
    
])

# %% [markdown]
# ##### Training the Model: This will be a convolutional Neural Network, train the network and measure the accuracy with the test dataset.

# %%
input_shape=(BATCH_SIZE, IMAGE_SIZE,IMAGE_SIZE,CHANNELS)
n_classes = 10
model = models.Sequential([
    resize_and_rescale,
    data_ugmentation,
    layers.Conv2D(32,(3,3),activation="relu", input_shape=input_shape),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64,(3,3),activation="relu"),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64,(3,3),activation="relu"),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64,(3,3),activation="relu"),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(64,(3,3),activation="relu"),
    layers.MaxPool2D((2,2)),
    layers.Flatten(),
    layers.Dense(64,activation = "relu"),
    layers.Dense(n_classes,activation = "softmax"),
    
])
model.build(input_shape=input_shape)
# Out:
# C:\Users\annla\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)              │ (32, 256, 256, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_1 (Sequential)            │ (32, 256, 256, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (32, 254, 254, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (32, 127, 127, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (32, 125, 125, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (32, 62, 62, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (32, 60, 60, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (32, 30, 30, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (32, 28, 28, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (32, 14, 14, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (32, 12, 12, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (32, 6, 6, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (32, 2304)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (32, 64)                    │         147,520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (32, 10)                    │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 278,346 (1.06 MB)
#  Trainable params: 278,346 (1.06 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer = "adam",
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics = ["accuracy"]
)

# %%
history = model.fit(
    train_ds,
    epochs = EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data = val_ds, 
)
# Out:
# Epoch 1/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 455s 1s/step - accuracy: 0.3451 - loss: 1.8207 - val_accuracy: 0.4944 - val_loss: 1.6630
# Epoch 2/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 437s 1s/step - accuracy: 0.6680 - loss: 0.9142 - val_accuracy: 0.7281 - val_loss: 0.7632
# Epoch 3/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 418s 1s/step - accuracy: 0.7741 - loss: 0.6328 - val_accuracy: 0.6781 - val_loss: 1.2026
# Epoch 4/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 363s 908ms/step - accuracy: 0.8170 - loss: 0.5147 - val_accuracy: 0.7513 - val_loss: 0.9018
# Epoch 5/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 294s 736ms/step - accuracy: 0.8445 - loss: 0.4293 - val_accuracy: 0.8525 - val_loss: 0.4201
# Epoch 6/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 302s 756ms/step - accuracy: 0.8853 - loss: 0.3337 - val_accuracy: 0.8163 - val_loss: 0.5600
# Epoch 7/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 295s 736ms/step - accuracy: 0.8852 - loss: 0.3315 - val_accuracy: 0.5775 - val_loss: 2.1539
# Epoch 8/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 272s 681ms/step - accuracy: 0.9007 - loss: 0.2969 - val_accuracy: 0.8250 - val_loss: 0.5808
# Epoch 9/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 284s 710ms/step - accuracy: 0.9204 - loss: 0.2257 - val_accuracy: 0.7881 - val_loss: 0.7610
# Epoch 10/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━
# Epoch 33/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 277s 691ms/step - accuracy: 0.9718 - loss: 0.0779 - val_accuracy: 0.9656 - val_loss: 0.1156
# Epoch 34/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 270s 676ms/step - accuracy: 0.9723 - loss: 0.0745 - val_accuracy: 0.9700 - val_loss: 0.0916
# Epoch 35/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 288s 721ms/step - accuracy: 0.9795 - loss: 0.0602 - val_accuracy: 0.9725 - val_loss: 0.0861
# Epoch 36/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 344s 859ms/step - accuracy: 0.9770 - loss: 0.0663 - val_accuracy: 0.9762 - val_loss: 0.0849
# Epoch 37/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 332s 830ms/step - accuracy: 0.9755 - loss: 0.0697 - val_accuracy: 0.9631 - val_loss: 0.1171
# Epoch 38/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 334s 835ms/step - accuracy: 0.9769 - loss: 0.0755 - val_accuracy: 0.9700 - val_loss: 0.0941
# Epoch 39/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 324s 810ms/step - accuracy: 0.9738 - loss: 0.0735 - val_accuracy: 0.9700 - val_loss: 0.0889
# Epoch 40/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 345s 864ms/step - accuracy: 0.9746 - loss: 0.0702 - val_accuracy: 0.9569 - val_loss: 0.1639
# Epoch 41/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 360s 899ms/step - accuracy: 0.9756 - loss: 0.0633 - val_accuracy: 0.9706 - val_loss: 0.0948
# Epoch 42/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 444s 1s/step - accuracy: 0.9773 - loss: 0.0676 - val_accuracy: 0.9625 - val_loss: 0.1397
# Epoch 43/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 444s 1s/step - accuracy: 0.9814 - loss: 0.0517 - val_accuracy: 0.9669 - val_loss: 0.1186
# Epoch 44/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 448s 1s/step - accuracy: 0.9753 - loss: 0.0681 - val_accuracy: 0.9381 - val_loss: 0.2218
# Epoch 45/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 439s 1s/step - accuracy: 0.9783 - loss: 0.0610 - val_accuracy: 0.9575 - val_loss: 0.1230
# Epoch 46/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 443s 1s/step - accuracy: 0.9748 - loss: 0.0745 - val_accuracy: 0.9606 - val_loss: 0.1383
# Epoch 47/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 451s 1s/step - accuracy: 0.9797 - loss: 0.0570 - val_accuracy: 0.9737 - val_loss: 0.0838
# Epoch 48/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 506s 1s/step - accuracy: 0.9810 - loss: 0.0524 - val_accuracy: 0.9750 - val_loss: 0.0875
# Epoch 49/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 462s 1s/step - accuracy: 0.9824 - loss: 0.0479 - val_accuracy: 0.9538 - val_loss: 0.1827
# Epoch 50/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 456s 1s/step - accuracy: 0.9823 - loss: 0.0513 - val_accuracy: 0.9656 - val_loss: 0.1107

# %%
score = model.evaluate(test_ds)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.9646 - loss: 0.0973

# %%
score
# Out:
# [0.09834327548742294, 0.965624988079071]

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 50, 'steps': 400}

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
acc= history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(range(EPOCHS),acc,label = 'Training Accuracy')
plt.plot(range(EPOCHS),val_acc,label = 'Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first Image to predict")
    plt.imshow(first_image)
    print("first image's actual label", class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("pridected label",class_names[np.argmax(batch_prediction[0])])
# Out:
# first Image to predict
# first image's actual label Tomato_Bacterial_spot
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# pridected label Tomato_Bacterial_spot

# %%
def predict(model,img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array,0) # create a batch
    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100*(np.max(predictions[0])),2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15,15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype('uint8'))

        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual:{actual_class},\n Predicted: {predicted_class}.")
        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step

# %%
import os
model_version = max([int(i) for i in os.listdir("../models")+[0]])+1
model.save(f"../models/{model_version}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
#       2 model_version = max([int(i) for i in os.listdir("../models")+[0]])+1
# ----> 3 model.save(f"../models/{model_version}")
#
# NameError: name 'model' is not defined

# %%
model.save("../tomatoes_model.h5")
